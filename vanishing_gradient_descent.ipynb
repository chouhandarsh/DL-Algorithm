# %%
import numpy as np
import pandas as pd
import tensorflow
from tensorflow import keras
from sklearn.datasets import make_moons
from keras.layers import Dense
from keras.models import Sequential
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785302831.393377   41930 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1785302832.521952   41930 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785302837.293474   41930 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
X,y=make_moons(n_samples=300,noise=0.05,random_state=42)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=y,s=100)
plt.show()

# %%
model = Sequential()
model.add(Dense(10,activation='sigmoid',input_dim=2))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /run/media/darshchouhan/New Volume/DL-Algorithm/venv/lib64/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1785302859.182813   41930 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
old_weight = model.get_weights()[0]

# %%
print(old_weight)
# Out:
# [[ 0.3682018  -0.12483054 -0.4908154  -0.41955298 -0.63868034  0.68695956
#    0.15264136 -0.40567976  0.45043916 -0.6831436 ]
#  [ 0.40670913 -0.27168298 -0.08320481  0.2317974  -0.33290312  0.16634452
#   -0.22634661  0.3438217  -0.18420231  0.5530477 ]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
model.fit(X_train,y_train,epochs=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5156 - loss: 0.6985

# %%
new_weight = model.get_weights()[0]

# %%
print(new_weight)
# Out:
# [[ 0.36819828 -0.12483897 -0.49081331 -0.41954282 -0.6386834   0.6869546
#    0.15264015 -0.4056837   0.45043728 -0.68314195]
#  [ 0.4067127  -0.27167493 -0.08320696  0.23178676 -0.3328997   0.16635033
#   -0.22634543  0.34382564 -0.18420035  0.55304587]]

# %%
gradient =   (old_weight-new_weight)/0.001
percentage_change = abs(100*(old_weight-new_weight)/old_weight)

# %%
gradient
# Out:
# array([[ 0.00351667,  0.00842661, -0.00208616, -0.01016259,  0.00303984,
#          0.00494719,  0.00120699,  0.00393391,  0.00187755, -0.00166893],
#        [-0.00357628, -0.00804663,  0.00215322,  0.01063943, -0.00342727,
#         -0.00581145, -0.00117719, -0.00393391, -0.00196695,  0.00184774]],
#       dtype=float32)

# %%
percentage_change
# Out:
# array([[0.00095509, 0.00675044, 0.00042504, 0.00242224, 0.00047596,
#         0.00072016, 0.00079074, 0.00096971, 0.00041683, 0.0002443 ],
#        [0.00087932, 0.00296177, 0.00258785, 0.00458997, 0.00102951,
#         0.00349362, 0.00052008, 0.00114417, 0.00106782, 0.0003341 ]],
#       dtype=float32)

# %%
model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5156 - loss: 0.6959
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5156 - loss: 0.6948
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5156 - loss: 0.6942
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5156 - loss: 0.6936
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5156 - loss: 0.6933
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5156 - loss: 0.6927
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5156 - loss: 0.6927
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5156 - loss: 0.6929
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5156 - loss: 0.6926
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5156 - loss: 0.6927
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5156 - loss: 0.6928
# Epoch 12/100
# ...

# %% [markdown]
# ## So handle vanishing gradient problems there are few tings to do
# - First is the dfecrease the complexity of the neural network we  can use the shallow neural network for the same so that the derivatives will be a smaller value
# - Second is that we will use the different activation function $ \textbf{relu}$ in which the function is max(0,z) it is not squeezing it also has the problem of the dying relu

# %% [markdown]
# ### Now we will use the same dataset with the relu

# %%
model = Sequential()
model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))

model.add(Dense(1,activation='sigmoid'))

# %%
model.compile

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5911 - loss: 0.6922
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5156 - loss: 0.6905
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5156 - loss: 0.6886
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5156 - loss: 0.6857
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5156 - loss: 0.6816
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5156 - loss: 0.6752
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5156 - loss: 0.6658
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5156 - loss: 0.6499
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5156 - loss: 0.6301
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5156 - loss: 0.6019
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5156 - loss: 0.5694
# Epoch 12/100
# ...
