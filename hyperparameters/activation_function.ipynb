# %% [markdown]
# # Sigmoid Activation

# %% [markdown]
# ### Activation Functions
# - In artificial Neural network each neuron forms a weighted sum of its inputs and passes the resulting scalar value to a function reffered as the activation function or the transfer function if a neuron has n inputs then the output of the activation function is

# %% [markdown]
# - It should be non linear
# - Activation should be differentiable
# - relu is not differentiable at 0
# - The calculation of derivative should be less expensive
# - It should be 0  centered that is normalized
# - It Should be non-saturating because the saturating function causes vanishing gradient problem

# %% [markdown]
# ### Sigmoid

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Advantage
# - It tells the probability
# - Use to capture the Non-Linearity of the data
# - Differentiable

# %% [markdown]
# ### Disadvantage
# - Saturating function causes vanishing gradient problem
# - It is non Zero-centered the numbers are not normalized due to which the training gets slow
# - The reason is

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The final output only depends on the a11 and a22 value as the previous is exact same so the final predicaion will always be of the same sign

# %% [markdown]
# # Tanh activation function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# f(x)=\frac{e^x-e^{-x}}{e^x+e^{-x}}
# $$
# $$
# f'(x)=(1-tan{h^2}(x))
# $$

# %% [markdown]
# ### Advantages
# 1) Non-Linear
# 2) Differentiable
# 3) Zero-Centered
# ### Disadvantage
# 1) Saturating function causes vanishing grtadient problem

# %% [markdown]
# # Relu Activation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# f(x) = max(0,x
# )
# $$

# %% [markdown]
# ### Advantage
# - Non Linear
# - Not Saturating in the +ve regions
# - Computational less expansive
# - Convergence is faseter
# ### Disadvantages
# - Non Differentiable at 0
# - Non Zero Centered
# - Dying Relu problem

# %% [markdown]
# ## Dying Relu - Rectified Linear Unit
# - Best choice for hidden layers
# - Dead Neuron is foemed
# ### Why the Dying Relu Occurs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### All this problem is caused to the weight being negative so
# - #### What are the resions for this term beign negative
# 1) High learning Rate W = w0 - n*dL/dw if lr will be high then this will become negative
# 2) High negative bias
# ### Solutions
# 1) To set low learning rates
# 2) Set the bias as point 0.1 this is proven to give the best result

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Leaky-Relu
# ![image.png](attachment:image.png)

# %% [markdown]
# - #### For Z greater than 0 we have Z and for Z less than 0 we have 1/100z due to which the small relu is circulating all over the node because of  which this dying relu is solved

# %% [markdown]
# #### Advantage
# 1) Non-Saturated -> Unbounded
# 2) Easily computed
# 3) No Dting Relu-Problem
# 4) Close to Zero Center

# %% [markdown]
# # Parameteric Relu
# - This that 0.01 is tranable parameter so it is like
# $$
# f(x) =
# \begin{cases}
# x, & \text{if } x > 0 \\
# ax, & \text{otherwise}
# \end{cases}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ELU Exponential Linear Unit
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# ELU = \begin{cases}
# x, & \text{if x>0} \\
# \alpha(e^x-1) & \text{if x<0}
# \end{cases}
# $$

# %% [markdown]
# ### Advantage
# 1) Close to Zero Centric
# 2) Comverges faseter
# 3) Better generalized
# 4) always continious and differenmtiable
# ### Disadvantage
# 1) Computationally more expensive

# %% [markdown]
# # SELU Scaled Exponential Linear Unit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# S.E.L.U(x) =\lambda
# \begin{cases}
# x & \text{if x>0} \\
# \alpha e^x- \alpha & if x <0
# \end{cases}
# $$

# %% [markdown]
# ### Advantage
# 1) the Result is Normalized in it
# 2) we can control om the basis of lamda
