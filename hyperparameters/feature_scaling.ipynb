# %%
import numpy as np
import pandas as pd
df = pd.read_csv("/run/media/darshchouhan/New Volume/DL-Algorithm/hyperparameters/Social_Network_Ads.csv")

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
import seaborn as sns

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(128,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /run/media/darshchouhan/New Volume/DL-Algorithm/venv/lib64/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1786379528.360909  217006 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.compile()
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 513 (2.00 KB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
hist = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=1000,)
# Out:
# Epoch 1/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5167 - loss: 97.7284 - val_accuracy: 0.7600 - val_loss: 60.0253
# Epoch 2/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5100 - loss: 96.5394 - val_accuracy: 0.7600 - val_loss: 14.0097
# Epoch 3/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4967 - loss: 107.4438 - val_accuracy: 0.2400 - val_loss: 16.5697
# Epoch 4/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4567 - loss: 33.2228 - val_accuracy: 0.2400 - val_loss: 67.0340
# Epoch 5/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4900 - loss: 103.7999 - val_accuracy: 0.2400 - val_loss: 138.5440
# Epoch 6/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4900 - loss: 101.6196 - val_accuracy: 0.2400 - val_loss: 58.6088
# Epoch 7/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5233 - loss: 44.1920 - val_accuracy: 0.7500 - val_loss: 7.8376
# Epoch 8/1000
# ...

# %%
hist.history
# Out:
# {'accuracy': [0.5166666507720947,
#   0.5099999904632568,
#   0.49666666984558105,
#   0.4566666781902313,
#   0.49000000953674316,
#   0.49000000953674316,
#   0.5233333110809326,
#   0.5366666913032532,
#   0.44333332777023315,
#   0.5433333516120911,
#   0.5099999904632568,
#   0.503333330154419,
#   0.49666666984558105,
#   0.5233333110809326,
#   0.49000000953674316,
#   0.44333332777023315,
#   0.5866666436195374,
#   0.5099999904632568,
#   0.5633333325386047,
#   0.4933333396911621,
#   0.5099999904632568,
#   0.47999998927116394,
#   0.5133333206176758,
#   0.47333332896232605,
#   0.5366666913032532,
#   0.5266666412353516,
#   0.5433333516120911,
#   0.503333330154419,
#   0.49000000953674316,
#   0.5400000214576721,
#   0.4699999988079071,
#   0.5166666507720947,
#   0.44999998807907104,
#   0.5333333611488342,
#   0.550000011920929,
#   0.5566666722297668,
#   0.5866666436195374,
#   0.5099999904632568,
#   0.5133333206176758,
#   0.43666666746139526,
# ...

# %%
sns.lineplot(hist.history['val_accuracy'])
# Out:
# <Axes: >

# %% [markdown]
# ## The Reason for this is that
# - Since the Salaray is large so the model dont pay attention on the other parameters due to which the training is not happening properly

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.histplot(df['EstimatedSalary'])
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler
model = StandardScaler()
X_train_scaled = model.fit_transform(X_train)
X_test_scaled = model.fit_transform(X_test)

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras import Sequential

# %%
model2 = Sequential()
model2.add(Dense(128,activation='relu',input_dim=2))
model2.add(Dense(1,activation='sigmoid'))
# Out:
# /run/media/darshchouhan/New Volume/DL-Algorithm/venv/lib64/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model2.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
X_train_scaled.shape
# Out:
# (300, 2)

# %%
y_train.shape[0]
# Out:
# 300

# %%
result =model2.fit(X_train_scaled,y_train,epochs=1000)
# Out:
# Epoch 1/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9367 - loss: 0.1706
# Epoch 2/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9367 - loss: 0.1703
# Epoch 3/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.1703
# Epoch 4/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.1706
# Epoch 5/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9467 - loss: 0.1704
# Epoch 6/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.1701
# Epoch 7/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.1702
# Epoch 8/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.1700
# Epoch 9/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.1703
# Epoch 10/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9467 - loss: 0.1701
# Epoch 11/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.1716
# ...

# %%
result.history
# Out:
# {'accuracy': [0.9366666674613953,
#   0.9366666674613953,
#   0.9399999976158142,
#   0.9433333277702332,
#   0.9466666579246521,
#   0.9433333277702332,
#   0.9433333277702332,
#   0.9433333277702332,
#   0.9433333277702332,
#   0.9466666579246521,
#   0.9399999976158142,
#   0.9399999976158142,
#   0.9399999976158142,
#   0.9433333277702332,
#   0.9399999976158142,
#   0.9433333277702332,
#   0.9433333277702332,
#   0.9399999976158142,
#   0.9366666674613953,
#   0.9366666674613953,
#   0.9399999976158142,
#   0.9399999976158142,
#   0.9366666674613953,
#   0.9433333277702332,
#   0.9399999976158142,
#   0.9399999976158142,
#   0.9366666674613953,
#   0.9366666674613953,
#   0.9366666674613953,
#   0.9366666674613953,
#   0.9433333277702332,
#   0.9466666579246521,
#   0.9466666579246521,
#   0.9433333277702332,
#   0.9466666579246521,
#   0.9433333277702332,
#   0.9433333277702332,
#   0.9399999976158142,
#   0.9433333277702332,
#   0.9433333277702332,
#   0.9466666579246521,
# ...

# %%
import seaborn as sns
sns.lineplot(result.history['loss'])
# Out:
# <Axes: >
