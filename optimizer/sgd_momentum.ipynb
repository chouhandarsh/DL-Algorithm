# %% [markdown]
# ### Problems with the normal gradent denscent  is that
# - It has teh high curvature
# - It has constant gradient
# - Noisy  gradient (Local Minima)

# %% [markdown]
# - Best reason  to use the momentum optimization is speed

# %% [markdown]
# In this what   we  do is that we add a velocity term in the end to control the movement in that direction
# $$
# W_\text{t-1}=w_t+V_t \\
# V_t = \beta*V_\text{t-1}+\eta
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# \beta \text{ decating factor}
# $

# %% [markdown]
# - The main problem with the momentum is that is stats to opssilate as we move to the minima
