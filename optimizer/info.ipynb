# %% [markdown]
# ## Problems with the gradient descent
# - Fist is that we dont have the correct  idea of lr
# - Second  is that in deep learning the dimentoion  of the data is too long due which same lr in the different  direction is not useful
# - we can stck in the local minima
# - Saddle point
# ![image.png](attachment:image.png)

# %% [markdown]
# - a point whre the slope dosent change in any of the direction
