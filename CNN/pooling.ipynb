# %% [markdown]
# ### Problem
# - One Problem with the image is that it is translation variance so the model learns with the position of the object in the image but this is not good because either the cat is i either part of the image still it is the cat so we have to take care of it This is called Translation Variance
# - we know tha the rbg is the 3D image and after applying filters its size increases and then we merge it so the size of grid becomes too large to load into the ram for this there is one technique called stride so that the repetation decreases and the

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pooling

# %% [markdown]
# - we know tha the rbg is the 3D image and after applying filters its size increases and then we merge it so the size of grid becomes too large to load into the ram for this there is one technique called stride so that the repetation decreases and the

# %% [markdown]
# ### Pooling is used to decrease the size  of the feature map
# - Min_Pooling
# - Max-Pooling
# - Average-Pooling
# - Average-Pooling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Conv2D,Flatten,MaxPool2D
from keras import Sequential
from keras.datasets import mnist
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786724696.694516  385191 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1786724696.819577  385191 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786724703.537194  385191 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
(X_train,y_train),(X_test,yy_test) = mnist.load_data()

# %%
model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 11, 11, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 3, 3, 32)       │         9,248 │
# ...

# %% [markdown]
# #### Advantages of pooling

# %% [markdown]
# 1) #### It Reduces the size of the of the mtrix
# 2) #### It makes the image translation-Invariant
# 3) #### Inhanced features in  case of mx-pooling
# 4) #### Threre is no need of training we just need to tell teh value of size of the krenal and the value of stride

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Types of pooling
# 1. Max Pooling
# 2. Avg Pooling
# 3. Global Pooling
#     1. Global Max Pooling
#     2. Global average pooling

# %% [markdown]
# ## Disadvantages
# 1) We Cant use pooling in the image segmentation task
# 2) we loose a lo t  of information while pooling
