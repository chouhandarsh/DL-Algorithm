# %% [markdown]
# ## Memoization
# - Memoization is a optimization technique used primerly to speed-up the computer programmes by storing the results of the  expensive function calls and returning the cashed result wehn the same input is given
