# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The problem with the LSTM was that it is a complex artitecture so that the training time in the case of LSTM was too-long

# %% [markdown]
# ## there are the problems that sometime the GRU perform well or sometime LSTM performs well

# %% [markdown]
# - In GRU there is simply one hidden state only

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - ## we are working with the same gate for the forgot gate and the current state gate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - so it is happeing in two steps so like for the previous state we are creating the candidate hidden state and from that candidate hidden state we are creating the current state

# %% [markdown]
# - we cannot directly make the current h-t cureve as the candidate  memory because it is heavly inclined towards the curerent sate so we will have to balance it  properly

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - the first thing happen by the reset gate and the second thing happen by the update gate zt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### First step is the calculation of R_t which is the vector with the same dimention of h_t-1
# - #### Why it is called the reset gate
# - - it means that we want to reset some of the information from the previous state
#  - ![image.png](attachment:image.png)
#  - in that r_t that 0.8 means that we want to retain the 80% of the previous information
#  - it is a form of gate that reset the

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - after getting the h_t tilt we have to decide that on which we have to give more importance to the current infomation or to the previous information so that when we are

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
