# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Forgot Gate removes the Unnecessary informations form the gate and
# ### Input Gate makes sure that if some new information is added then it is added into the memory
# ### Output Gate fianlly gives the output response and it also creates the sort term memory

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # F1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Forget Gate
# - We are using Forget gate here beacause when we the memory from the previous Gate is MUltiplied with  number lesser than 1 then it forgert the things like its value is decreases
# - Ft has the power to control how much information will be transfered or carried out

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The Second Gate  Input Gate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The main feature of input gate is that whenver some new information will apprear then we will have to add that informato=ion into the  Ct-1 so we are using the  input gate

# %% [markdown]
# - Ct is long term context it is like the information that an algorith things that it can be some useful information so we will add it into the long term context
# - In second stage from ct we find that exacat information that will be added into the current state
# - In the third state we will add those information and we will get the final state and the final reponse

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Output-Gate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - #### In this we take the ct and perform a elementary row operation on it and after that we get get somethig then again we add or drop some of the information form it using the other sigmoid function and finally we get the ht which is then used to pass to the other state
